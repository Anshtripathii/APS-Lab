# %% [markdown]
# <a href="https://colab.research.google.com/github/Anshtripathii/APS-Lab/blob/main/Lab_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Shortest Path Using Dijkstra Algorithm in Python
# Problem Description:
# Given a weighted graph with non negative edge weights. Find the shortest distance from a source vertex to all other vertices using Dijkstra algorithm

# %% [markdown]
# #Theory
# Dijkstra algorithm finds shortest distance from one source node to all other nodes in a weighted graph with non negative weights. Dictionary structure stores nodes as keys and neighbor nodes with weights as values.
#
# ##Algorithm Steps
#
# 1. Represent graph using dictionary.
# 2. Set distance of every node as infinity.
# 3. Set distance of source node as 0.
# 4. Select node with smallest distance among unvisited nodes.
# 5. Update distance of neighbor nodes.
# 6. Repeat until all nodes get visited.

# %%
def dijkstra(graph, start):

    distances = {}
    visited = []

    for node in graph:
        distances[node] = float('inf')

    distances[start] = 0

    while len(visited) < len(graph):

        min_node = None
        min_distance = float('inf')

        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node

        visited.append(min_node)

        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight

            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance

    return distances

# %%
graph = {
'A': {'B': 4, 'C': 2},
'B': {'A': 4, 'C': 5, 'D': 10},
'C': {'A': 2, 'B': 5, 'D': 3},
'D': {'B': 10, 'C': 3}
}

result = dijkstra(graph, 'A')

for node in result:
    print("Distance from A to", node, "=", result[node])
# Out:
# Distance from A to A = 0
# Distance from A to B = 4
# Distance from A to C = 2
# Distance from A to D = 5

# %% [markdown]
# Now, let's implement
# 1. Modify program for user input graph using dictionary.
# 2. Display shortest path with total distance.
# 3. Add two more nodes in graph.
# 4. Test algorithm with different source nodes.

# %%
graph = {}

# Input for number of nodes with validation
while True:
    try:
        n = int(input("Enter number of nodes: "))
        if n < 0:
            print("Number of nodes cannot be negative. Please enter a non-negative integer.")
            continue
        break
    except ValueError:
        print("Invalid input. Please enter an integer for the number of nodes.")

for _ in range(n):
    node = input(f"\nEnter node name (e.g., A, B, C): ")
    # Basic validation for node name to avoid empty strings
    while not node.strip():
        node = input("Node name cannot be empty. Please enter a node name: ")
    graph[node] = {}

    # Input for number of neighbors with validation
    while True:
        try:
            m = int(input(f"Enter number of neighbors for {node}: "))
            if m < 0:
                print("Number of neighbors cannot be negative. Please enter a non-negative integer.")
                continue
            break
        except ValueError:
            print("Invalid input. Please enter an integer for the number of neighbors.")

    for _ in range(m):
        neighbor = input(f"  Enter neighbor for {node}: ")
        # Basic validation for neighbor name
        while not neighbor.strip():
            neighbor = input("  Neighbor name cannot be empty. Please enter a neighbor name: ")

        # Input for weight with validation
        while True:
            try:
                weight = int(input(f"  Enter weight for edge {node}-{neighbor}: "))
                if weight < 0:
                    print("Weight cannot be negative. Please enter a non-negative integer.")
                    continue
                break
            except ValueError:
                print("Invalid input. Please enter an integer for the weight.")
        graph[node][neighbor] = weight

print("\nGraph entered by user:")
print(graph)
# Out:
# Enter number of nodes: 3
#
# Enter node name (e.g., A, B, C): A
# Enter number of neighbors for A: 2
#   Enter neighbor for A: B
#   Enter weight for edge A-B: 4
#   Enter neighbor for A: C
#   Enter weight for edge A-C: 2
#
# Enter node name (e.g., A, B, C): B
# Enter number of neighbors for B: A
# Invalid input. Please enter an integer for the number of neighbors.
# Enter number of neighbors for B: 1
#   Enter neighbor for B: A
#   Enter weight for edge B-A: 2
#
# Enter node name (e.g., A, B, C): C
# Enter number of neighbors for C: 1
#   Enter neighbor for C: A
#   Enter weight for edge C-A: 2
#
# Graph entered by user:
# {'A': {'B': 4, 'C': 2}, 'B': {'A': 2}, 'C': {'A': 2}}

# %%
import heapq

def dijkstra(graph, start):
    distances = {node: float('inf') for node in graph}
    previous = {node: None for node in graph}

    distances[start] = 0
    pq = [(0, start)]

    while pq:
        current_distance, current_node = heapq.heappop(pq)

        if current_distance > distances[current_node]:
            continue

        for neighbor, weight in graph[current_node].items():
            distance = current_distance + weight

            if distance < distances[neighbor]:
                distances[neighbor] = distance
                previous[neighbor] = current_node
                heapq.heappush(pq, (distance, neighbor))

    return distances, previous


def get_path(previous, start, end):
    path = []
    current = end

    while current is not None:
        path.append(current)
        current = previous[current]

    path.reverse()

    if path[0] == start:
        return path
    return []


graph = {
    'A': {'B': 4, 'C': 2},
    'B': {'A': 4, 'C': 5, 'D': 10},
    'C': {'A': 2, 'B': 5, 'D': 3},
    'D': {'B': 10, 'C': 3}
}

start = input("Enter source node: ")

distances, previous = dijkstra(graph, start)

print("\nShortest paths:\n")

for node in graph:
    path = get_path(previous, start, node)

    if distances[node] == float('inf'):
        print(f"{start} → {node}: No path")
    else:
        print(f"{start} → {node}: Path = {' -> '.join(path)}, Distance = {distances[node]}")
# Out:
# Enter source node: A
#
# Shortest paths:
#
# A → A: Path = A, Distance = 0
# A → B: Path = A -> B, Distance = 4
# A → C: Path = A -> C, Distance = 2
# A → D: Path = A -> C -> D, Distance = 5

# %%
import heapq

def dijkstra(graph, start):
    distances = {node: float('inf') for node in graph}
    previous = {node: None for node in graph}

    distances[start] = 0
    pq = [(0, start)]

    while pq:
        current_distance, current_node = heapq.heappop(pq)

        if current_distance > distances[current_node]:
            continue

        for neighbor, weight in graph[current_node].items():
            distance = current_distance + weight

            if distance < distances[neighbor]:
                distances[neighbor] = distance
                previous[neighbor] = current_node
                heapq.heappush(pq, (distance, neighbor))

    return distances, previous


def get_path(previous, start, end):
    path = []
    current = end

    while current is not None:
        path.append(current)
        current = previous[current]

    path.reverse()

    if path[0] == start:
        return path
    return []



graph = {
    'A': {'B': 4, 'C': 2},
    'B': {'A': 4, 'C': 5, 'D': 10, 'E': 3},
    'C': {'A': 2, 'B': 5, 'D': 3, 'F': 8},
    'D': {'B': 10, 'C': 3, 'E': 1},
    'E': {'B': 3, 'D': 1, 'F': 6},
    'F': {'C': 8, 'E': 6}
}


start = input("Enter source node: ")

distances, previous = dijkstra(graph, start)

print("\nShortest paths:\n")

for node in graph:
    path = get_path(previous, start, node)

    if distances[node] == float('inf'):
        print(f"{start} → {node}: No path")
    else:
        print(f"{start} → {node}: Path = {' -> '.join(path)}, Distance = {distances[node]}")
# Out:
# Enter source node: A
#
# Shortest paths:
#
# A → A: Path = A, Distance = 0
# A → B: Path = A -> B, Distance = 4
# A → C: Path = A -> C, Distance = 2
# A → D: Path = A -> C -> D, Distance = 5
# A → E: Path = A -> C -> D -> E, Distance = 6
# A → F: Path = A -> C -> F, Distance = 10

# %%
import heapq

def dijkstra(graph, start):
    distances = {node: float('inf') for node in graph}
    previous = {node: None for node in graph}

    distances[start] = 0
    pq = [(0, start)]

    while pq:
        current_distance, current_node = heapq.heappop(pq)

        if current_distance > distances[current_node]:
            continue

        for neighbor, weight in graph[current_node].items():
            distance = current_distance + weight

            if distance < distances[neighbor]:
                distances[neighbor] = distance
                previous[neighbor] = current_node
                heapq.heappush(pq, (distance, neighbor))

    return distances, previous


def get_path(previous, start, end):
    path = []
    current = end

    while current is not None:
        path.append(current)
        current = previous[current]

    path.reverse()

    if path[0] == start:
        return path
    return []


# Graph with extra nodes
graph = {
    'A': {'B': 4, 'C': 2},
    'B': {'A': 4, 'C': 5, 'D': 10, 'E': 3},
    'C': {'A': 2, 'B': 5, 'D': 3, 'F': 8},
    'D': {'B': 10, 'C': 3, 'E': 1},
    'E': {'B': 3, 'D': 1, 'F': 6},
    'F': {'C': 8, 'E': 6}
}



while True:
    start = input("\nEnter source node (or type 'exit' to stop): ")

    if start.lower() == 'exit':
        print("Program ended.")
        break

    if start not in graph:
        print("Invalid node! Try again.")
        continue

    distances, previous = dijkstra(graph, start)

    print(f"\nShortest paths from {start}:\n")

    for node in graph:
        path = get_path(previous, start, node)

        if distances[node] == float('inf'):
            print(f"{start} → {node}: No path")
        else:
            print(f"{start} → {node}: Path = {' -> '.join(path)}, Distance = {distances[node]}")
# Out:
# Enter source node (or type 'exit' to stop): A
#
# Shortest paths from A:
#
# A → A: Path = A, Distance = 0
# A → B: Path = A -> B, Distance = 4
# A → C: Path = A -> C, Distance = 2
# A → D: Path = A -> C -> D, Distance = 5
# A → E: Path = A -> C -> D -> E, Distance = 6
# A → F: Path = A -> C -> F, Distance = 10
#
# Enter source node (or type 'exit' to stop): exit
# Program ended.
